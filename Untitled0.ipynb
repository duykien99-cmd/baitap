# %%
while True:
  try:
    n=int(input())
    if n>0:
      break
    else:
      print("vui long nhap so lon hon 0")
  except ValueError:
    print("vui long nhap so nguyen")
def so(a):
  if a==1:
    return False
  if a==2:
    return True
  for i in range(3,n):
    if a%i==0:
     return False
  return True
if so(n):
  print("la so nguyen to")
else:
  print("day kh phai so nguyen so")
# Out:
# 6
# day kh phai so nguyen so

# %%
#w3a2
a=1
b=0
b=b^a
a=b^a
print(a)
print(b)
# Out:
# 0
# 1

# %%
#w3a3
#kiem tra xem 1 so co phai luy thua cua 2 hay kh
n=int(input())
def so(a):
  for i in range(0,a+1):
    if 2**i==a:
      return True
  return False
if so(n):
  print(n,"la luy thua cua 2")
else:
  print("day kh phai luy thua cua 2")
# Out:
# 9
# day kh phai luy thua cua 2

# %%
#w3a4
m=float(input())
n=float(input())
b=m//n
print(b)
# Out:
# 6
# 4
# 1.0

# %%
#w3a5
m=float(input())
n=float(input())
b=m//n
a=b+1
print(a)
# Out:
# 6
# 4
# 2.0

# %%
#w3a6
x=int(input())
if x%2==0:
  print("even")
else:
  print("odd")
# Out:
# 8
# even

# %%
#w3a7
a,b=map(int,input().split())
if a<0 and b<0:
  print("yes")
else:
  print("no")
# Out:
# 1 2
# no

# %%
#w3a8
a=input()
b=input()
if len(a)>len(b):
  print(True)
else:
  print(False)
# Out:
# xin chao
# he lo
# True

# %%
#w3a9
a,b,c=map(int,input().split())
if (a+b>c or a+c>b or b+c>a) and a>0 and b>0 and c>0:
  print("yes")
else:
  print("no")
# Out:
# 1 2 5
# yes

# %%
#w3a10
a,b,c,d=map(int,input().split())
max=a
if b>max:
  max=b
if d>max:
  max=d
if c>max:
  max =c
print(max)
# Out:
# 4 2 1 3
# 4

# %%
#w3a11
a,b,c=map(int,input().split())
if (a+b>c or a+c>b or b+c>a) and a>0 and b>0 and c>0:
  if a==b==c:
    print("day la tam giac deu")
  elif a==b!=c or a==c!=b or b==c!=a:
    print("day la tam giac can")
  else:
    print("day la tam giac thuong")
else:
  print("day kh tao nen 1 tam giac")
# Out:
# 6 6 6
# day la tam giac deu

# %%
#w3a12
while True:
  try:
    n=int(input())
    if n>0:
      break
    else:
      print("vui long nhap so nguyen duong")
  except ValueError:
    print("vui long nhap so nguyen")
if (n%4==0 and n%100!=0) or n%400==0:
  print("nam do la nam nhuan")
else:
  print("nam do kh phai nam nhuan")
# Out:
# 2124
# nam do la nam nhuan

# %%
#w3a14
#giai pt ax+b=0
a=int(input())
b=int(input())
if a==0 and b==0:
  print("pt tren vo so nghiem")
elif a==0 and b!=0:
  print("pt tren vo nghiem")
else:
  x=-b/a
  print(round(x,2))
# Out:
# 6
# 4
# -0.67

# %%
#w3a15
diemtb=float(input())
if diemtb<10.0:
  if diemtb>8.0:
    print("gioi")
  elif diemtb<8.0 and diemtb>=6.5:
    print("kha")
  elif diemtb>5.0 and diemtb<6.5:
    print("trung binh")
  else:
    print("yeu")
# Out:
# 5.6
# trung binh

# %%
#w3a16
n=float(input())
a=int(n)
if n-a>=0.5:
  a+=1
  print(a)
else:
  print(a)
# Out:
# 6.4
# 6

# %%
#w3a17
a,b,c,d=map(float,input().split())
x=b/a
if c==b*x and d==c*x:
  print("co tao thanh 1 cap so nhan")
else:
  print("kh tao than 1 cap so nhan")
# Out:
# 2 4 8 16
# co tao thanh 1 cap so nhan
